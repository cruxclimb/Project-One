# %%
import os
import csv
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import json
# import seaborn as sns
# import ast

import collections
import pandas as pd
import numpy as np
import requests
import time
import datetime
# Import API key
#from api_keys import api_key

# %%
file_to_load = "Resources/traffic_collision_LA.csv"
# collision_df = pd.read_csv(file_to_load, delimiter=',', encoding="utf-8")
collision_df = pd.read_csv('Resources/traffic_collision_LA.csv')

# filepath = os.path.join("Resources", "socrata_metadata.json")
# with open(filepath) as jsonfile:
#     socrate_json = json.load(jsonfile)

collision_df.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  190817451  2019-10-26T00:00:00.000  2019-10-26T00:00:00.000           1230
# 1  191519526  2019-10-26T00:00:00.000  2019-10-26T00:00:00.000           1310
# 2  192019001  2019-10-26T00:00:00.000  2019-10-26T00:00:00.000            900
# 3  191615731  2019-10-26T00:00:00.000  2019-10-26T00:00:00.000             30
# 4  190918910  2019-10-26T00:00:00.000  2019-10-26T00:00:00.000            130
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0        8      West LA                 841         997
# 1       15  N Hollywood                1554         997
# 2       20      Olympic                2042         997
# 3       16     Foothill                1687         997
# 4        9     Van Nuys                 914         997
#
#   Crime Code Description MO Codes  ...  Premise Description  \
# 0      TRAFFIC COLLISION      NaN  ...               STREET
# ...

# %%
# collision_df_v2 = collision_df.dropna(how='any')
# Total_count=collision_df['Address'].count()

HWY_road=collision_df[collision_df['Address'].str.contains("HWY")]
# Highway_road_a=collision_df[collision_df['Address'].str.contains("HIGHWAY ")]
# Highway_road_b=collision_df[collision_df['Address'].str.contains(" HIGHWAY")]
# HY_road=collision_df[collision_df['Address'].str.contains(" HY")]

HWY_road_count=HWY_road["Address"].count()
# Highway_road_a_count=Highway_road_a["Address"].count()
# Highway_road_b_count=Highway_road_b["Address"].count()
# HY_road_count=HY_road["Address"].count()
# Highways_count=HWY_road_count+Highway_road_a_count+Highway_road_b_count+HY_road_count
# Highways_coll_percent=100*Highways_count/Total_count




FY_road=collision_df[collision_df['Address'].str.contains(" FY")]
FY_road_count=FY_road["Address"].count()
Freeway_road_a=collision_df[collision_df['Address'].str.contains(" FREEWAY")]
Freeway_road_a_count=Freeway_road_a["Address"].count()
# Freeway_road_b=collision_df[collision_df['Address'].str.contains("FREEWAY ")]
# Freeway_road_b_count=Freeway_road_b['Address'].count()
FWY_road=collision_df[collision_df['Address'].str.contains("FWY")]
FWY_road_count=FWY_road['Address'].count()
# FRWY_road=collision_df[collision_df['Address'].str.contains(" FRWY")]
# FRWY_road_count=FRWY_road['Address'].count()
# Freeways_count=FY_road_count+Freeway_road_a_count+Freeway_road_b_count+FWY_road_count+FRWY_road_count

# Park_Lot=collision_df[collision_df['Premise Description'].str.contains(" LOT")]
# Park_Lot_count=Park_Lot['Premise Description'].count()



# FY_road_count
FWY_road_count
# Out:
# 68

# %%
Total_count=collision_df['Address'].count()
#highways
HWY_count=15
Highway_count=4
Hy_count=3898
Highway=HWY_count+Highway_count+Hy_count

#freeways
FY_count=848
Freeway_count=34
FWY_count=67
FRWY_count=16
Freeway=FY_count+Freeway_count+FWY_count+FRWY_count
#parking
ParkingLot_count=0
UNDERGROUND_PARKING=0
MTA_PROPERTY_PARKING_LOT=0
for value in collision_df["Premise Description"]: 
    if value == "PARKING LOT":
        ParkingLot_count+=1
    elif value=="PARKING UNDERGROUND/BUILDING":
        UNDERGROUND_PARKING+=1
    elif value=="MTA PROPERTY OR PARKING LOT":
        MTA_PROPERTY_PARKING_LOT+=1
Parking=ParkingLot_count+UNDERGROUND_PARKING+MTA_PROPERTY_PARKING_LOT
Others=Total_count-(Highway+Freeway+Parking)
percent_highway=100*Highway/Total_count
percent_freeway=100*Freeway/Total_count
percent_parking=100*Parking/Total_count
percent_other_roadTypes=100*Others/Total_count

print(f"{percent_highway} {percent_freeway} {percent_parking} {percent_other_roadTypes}")
# Out:
# 0.7873889122293539 0.1939827164414926 3.241622057342497 95.77700631398666

# %%
# #bars
# plt.rcParams["font.weight"] = "bold"
# import matplotlib

plt.figure(figsize=(30,20))
# fig = plt.figure()
plt.rcParams["font.weight"] = "bold"
Percent_Roadcollision=[percent_highway,percent_freeway,percent_parking,percent_other_roadTypes]
y_axis=Percent_Roadcollision

Name_roads=["Highway","Freeways","Parkings","Other locations"]

x_axis=np.arange(0, len(Name_roads))
tick_locations=[]
for x in x_axis:
    tick_locations.append(x)


plt.xticks(tick_locations, Name_roads,rotation=45)
plt.bar(x_axis, y_axis, facecolor="red", width = 0.9, alpha=0.75, align="center")
Bar_chart=plt.bar(x_axis, y_axis, facecolor="red", width = 0.9, alpha=0.75, align="center")
plt.ylabel("% Collusion percentage")

bars_percent=[percent_highway,percent_freeway,percent_parking,percent_other_roadTypes]

def percent_label(labels):
    for ii,label in enumerate(labels):
        height = label.get_height()
        plt.text(label.get_x()+label.get_width()/2., 0.08*height, '%s'% (int(Percent_Roadcollision[ii]))+'%',
                ha='center', va='bottom',color='black')
percent_label(Bar_chart)

plt.rcParams.update({'font.size':60})



plt.savefig("Images/Num_coll_vs_roadTypes.png")

# %%
# x = "HARBORFY                       FY".split()[1]
# x in ("FY")
# "    HEY     HIGHWAY    ".strip()

# %%
# HWY_cells=[]
# for cells in collision_df['Address']:
#     x=cells.split()[1]
#     HWY_cells.append(x)

# %%
# import re
# collision_df = collision_df.dropna(how='any')
# HWY_collision_df=collision_df['Address']
# HWY_list=[]

# # for HWY_cells in HWY_collision_df:
# #     keep = ['HWY']
# #     HWY=re.sub(r'\b\w+\b', lambda w: w.group() if w.group() in keep else , HWY_cells)
# #     HWY_list.append(HWY)
# ######
# # for HWY_cells in HWY_collision_df:
# #     m = re.search('.*\d{HWY}', HWY_cells)
# #     if m:
# #          HWY_cells = m.group(0)

# #     print(HWY_cells)
# #######
# count=0
# for HWY_cells in HWY_collision_df:
#     if "HWY" in HWY_cells:
#         count=count+1
#         words=HWY_cells.split()
#         HWY_list.append(words[-1])
        
# HWY_list
# count

# %%
# # avg = group.loc[group['name'].str.contains('chevrolet'), 'mpg'].mean()
# fy_df =collision_df[collision_df["Address"].str.contains("FY")].value_counts()
# fy_df
# #########sa premise description-ov e hashvats(vory erevi chisht chi qani vor frewaynery street e grats)
# Total_count=collision_df['Premise Description'].count()
# FREEWAY=0
# ParkingLot_count=0
# UNDERGROUND_PARKING=0
# MTA_PROPERTY_PARKING_LOT=0
# STREET=0
# for value in collision_df["Premise Description"]: 
#     if value == "PARKING LOT":
#         ParkingLot_count+=1
#     elif value=="PARKING UNDERGROUND/BUILDING":
#         UNDERGROUND_PARKING+=1
#     elif value=="MTA PROPERTY OR PARKING LOT":
#         MTA_PROPERTY_PARKING_LOT+=1
#     elif value=="FREEWAY":
#         FREEWAY+=1
#     elif value=="STREET":
#         STREET+=1
# Parking=ParkingLot_count+UNDERGROUND_PARKING+MTA_PROPERTY_PARKING_LOT
# Others=Total_count-(STREET+Parking+FREEWAY)
# Parking_percent=100*Parking/Total_count
# Street_percent=100*STREET/Total_count
# Freeway_percent=100*FREEWAY/Total_count
# Others_percent=100*Others/Total_count
# print(Parking," ", FREEWAY," ", STREET, " ",Others)
# Percent_Roadcollision=[Parking_percent,Street_percent,Freeway_percent,Others_percent]

# %%
###pie
# sizes = [Parking, FREEWAY,STREET, Others]
# labels = ["Parkings", "Freeways", "City street", "Other locations"]
# colors = ["lightcoral", "orange","red","lightskyblue"]
# explode = (0, 0, 0.2, 0)
# plt.pie(sizes, explode=explode, labels=labels, colors=colors,
#         autopct="%1.1f%%", shadow=True, startangle=140)
# plt.savefig("Images/Num_coll_vs_location.png")
# # plt.show()
# #bars
# fig = plt.figure()
# plt.rcParams["font.weight"] = "bold"

# y_axis=Percent_Roadcollision
# Name_roads=["Parkings", "Freeways", "City street", "Other locations"]

# x_axis=np.arange(0, len(Name_roads))
# tick_locations=[]
# for x in x_axis:
#     tick_locations.append(x)

# plt.xticks(tick_locations, Name_roads,rotation=45)
# plt.bar(x_axis, y_axis, facecolor="red", width = 0.6, alpha=0.75, align="center")
# # plt.text(x_axis,Percent_Roadcollision)
# # def percentONbar(labels):
# #     for ii,label in enumerate(labels):
# #         height = label.get_height()
# #         plt.text(label.get_x()+label.get_width()/2., 0.08*height, '%s'% (int(Percent_Roadcollision[ii]))+'%',
# #                 ha='center', va='bottom',color='white')


# # percentONbar(Percent_Roadcollision)

# plt.savefig("Images/Num_coll_vs_location.png")
# fig.show()

# %%
# for a in collision_df['Date Occurred']:
#     datee = datetime.datetime.strptime(a, "%Y-%m-%d %H:%M:%S")
#     datee.month
month_list=[]
year_list=[]
for a in collision_df['Date Occurred']:
    a.split('-')
    year,month,date=a.split('-')
    month_list.append(month)
    year_list.append(year)
#
#         a.split('-')
# a[1]
January=[]
February=[]
March=[]
April=[]
May=[]
June=[]
July=[]
August=[]
September=[]
October=[]
November=[]
December=[]

for i in month_list:
    if (i=='01'):
        January.append(i)
    elif (i=='02'):
        February.append(i)   
    elif (i=='03'):
        March.append(i)
    elif (i=='04'):
        April.append(i)
    elif (i=='05'):
        May.append(i)
    elif (i=='06'):
        June.append(i)
    elif (i=='07'):
        July.append(i)
    elif (i=='08'):
        August.append(i)
    elif (i=='09'):
        September.append(i)
    elif (i=='10'):
        October.append(i)
    elif (i=='11'):
        November.append(i)
    elif (i=='12'):
        December.append(i)
Num_January=len(January)    
Num_February=len(February) 
Num_March=len(March)
Num_April=len(April) 
Num_May=len(May) 
Num_June=len(June) 
Num_July=len(July) 
Num_August=len(August) 
Num_September=len(September) 
Num_October=len(October) 
Num_November=len(November) 
Num_December=len(December)

# %%
year_2010=[]
year_2011=[]
year_2012=[]
year_2013=[]
year_2014=[]
year_2015=[]
year_2016=[]
year_2017=[]
year_2018=[]
year_2019=[]
for i in year_list:
    if (i=='2010'):
        year_2010.append(i)
    elif (i=='2011'):
        year_2011.append(i) 
    elif (i=='2012'):
        year_2012.append(i)
    elif (i=='2013'):
        year_2013.append(i)
    elif (i=='2014'):
        year_2014.append(i)
    elif (i=='2015'):
        year_2015.append(i)
    elif (i=='2016'):
        year_2016.append(i)
    elif (i=='2017'):
        year_2017.append(i)
    elif (i=='2018'):
        year_2018.append(i)
    elif (i=='2019'):
        year_2019.append(i)
        
Num_2010=len(year_2010)
Num_2011=len(year_2011)
Num_2012=len(year_2012)
Num_2013=len(year_2013)
Num_2014=len(year_2014)
Num_2015=len(year_2015)
Num_2016=len(year_2016)
Num_2017=len(year_2017)
Num_2018=len(year_2018)
Num_2019=len(year_2019)

# %%
plt.rcParams["font.weight"] = "bold"
List_num_year=[Num_2010,Num_2011,Num_2012,Num_2013,Num_2014,Num_2015,Num_2016,Num_2017,Num_2018,Num_2019]
Name_year=["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"]
y_axis=List_num_year
x_axis=np.arange(0, len(Name_year))
tick_locations=[]
for x in x_axis:
    tick_locations.append(x)
    
plt.xticks(tick_locations, Name_year,rotation=45)
plt.bar(x_axis, y_axis, facecolor="red", width = 0.6, alpha=0.75, align="center")

plt.savefig("Images/Num_coll_vs_years.png")

# %%
plt.rcParams["font.weight"] = "bold"
List_num_month=[Num_January,Num_February,Num_March,Num_April,Num_May,Num_June,Num_July,Num_August,Num_September,Num_October,Num_November,Num_December]
y_axis=List_num_month
Name_months=["January","February","March","April","May","June","July","August","September","October","November","December"]
y_axis=List_num_month
x_axis=np.arange(0, len(Name_months))
tick_locations=[]
for x in x_axis:
    tick_locations.append(x)

# x_axis=len(List_num_month)

plt.xticks(tick_locations, Name_months,rotation=90)
plt.bar(x_axis, y_axis, facecolor="green", width = 0.6, alpha=0.75, align="center")

plt.savefig("Images/Num_coll_vs_month.png")

# %%
# Days=[]
# for a in collision_df['Date Occurred']:
#     a.split('-')
#     date=a.split('T')
  
# #   year,month,date=a.split('-')
#     Days.append(date)
# Days
####
Dates=[]
Days=[]
for a in collision_df['Date Occurred']:
    day=a.replace('T00:00:00.000','')
    Dates.append(day)
for i in Days:
    year,month,date=i.split('-')
    Days.append(month)
Days
###

# day_list=[]
# for day in Days:
#     day.split('-')
#     year,month,date=day.split('-')
#     day_list.append(date)
# day_list
# Out:
# []
